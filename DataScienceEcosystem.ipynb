# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# En este cuaderno se presenta un resumen de las principales herramientas y ecosistemas utilizados en la ciencia de datos.

# %% [markdown]
# Algunos de los lenguajes Utilizadas por los científicos de datos son:
#
# - Python
# - R
# - SQL
# - Scala

# %% [markdown]
# Algunas de las bibliotecas utilizadas por los científicos de datos son:
#
# - Pandas
# - NumPy
# - Matplotlib

# %% [markdown]
# | Herramientas de Ciencia de Datos |
# |----------------------------------|
# | Jupyter Notebook                 |
# | RStudio                          |
# | Apache Zeppelin                  |

# %% [markdown]
# ### A continuación, se presentan algunos ejemplos de evaluación de expresiones aritméticas en Python.

# %%
# Esta es una expresión aritmética simple para multiplicar y luego sumar enteros
(3*4)+5
# Out:
# 17
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
# Esto convertirá 200 minutos a horas dividiendo por 60
200/60

# %% [markdown]
# **Objetivos:**
#
# - Mencionar los lenguajes más usados en Ciencia de Datos
# - Señalar las bibliotecas más comunes entre los científicos de datos
# - Mostrar herramientas de desarrollo de código abierto empleadas en esta área
# - Explicar con ejemplos sencillos algunas expresiones aritméticas en Python

# %% [markdown]
# ## Autor
# Adrián Víctor Sihuenta Picón
